# %%
import pandas as pd

data = pd.read_csv('./dados_gas/gas_preco.csv', sep = '\t')

# %%
data
# Out:
#        DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0        2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1        2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2        2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3        2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4        2004-05-09  2004-05-15      NORDESTE             ALAGOAS
# ...             ...         ...           ...                 ...
# 120818   2021-04-25  2021-05-01         NORTE             RORAIMA
# 120819   2021-04-25  2021-05-01           SUL      SANTA CATARINA
# 120820   2021-04-25  2021-05-01       SUDESTE           SAO PAULO
# 120821   2021-04-25  2021-05-01      NORDESTE             SERGIPE
# 120822   2021-04-25  2021-05-01         NORTE           TOCANTINS
#
#                  PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0       ETANOL HIDRATADO                           127              R$/l
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 120823 entries, 0 to 120822
# Data columns (total 18 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   DATA INICIAL                   120823 non-null  object
#  1   DATA FINAL                     120823 non-null  object
#  2   REGIÃO                         120823 non-null  object
#  3   ESTADO                         120823 non-null  object
#  4   PRODUTO                        120823 non-null  object
#  5   NÚMERO DE POSTOS PESQUISADOS   120823 non-null  int64
#  6   UNIDADE DE MEDIDA              120823 non-null  object
#  7   PREÇO MÉDIO REVENDA            120823 non-null  float64
#  8   DESVIO PADRÃO REVENDA          120823 non-null  float64
#  9   PREÇO MÍNIMO REVENDA           120823 non-null  float64
#  10  PREÇO MÁXIMO REVENDA           120823 non-null  float64
#  11  MARGEM MÉDIA REVENDA           120823 non-null  object
# ...

# %%
data.isnull().sum()
# Out:
# DATA INICIAL                     0
# DATA FINAL                       0
# REGIÃO                           0
# ESTADO                           0
# PRODUTO                          0
# NÚMERO DE POSTOS PESQUISADOS     0
# UNIDADE DE MEDIDA                0
# PREÇO MÉDIO REVENDA              0
# DESVIO PADRÃO REVENDA            0
# PREÇO MÍNIMO REVENDA             0
# PREÇO MÁXIMO REVENDA             0
# MARGEM MÉDIA REVENDA             0
# COEF DE VARIAÇÃO REVENDA         0
# PREÇO MÉDIO DISTRIBUIÇÃO         0
# DESVIO PADRÃO DISTRIBUIÇÃO       0
# PREÇO MÍNIMO DISTRIBUIÇÃO        0
# PREÇO MÁXIMO DISTRIBUIÇÃO        0
# COEF DE VARIAÇÃO DISTRIBUIÇÃO    0
# dtype: int64

# %%
data.isna().sum()
# Out:
# DATA INICIAL                     0
# DATA FINAL                       0
# REGIÃO                           0
# ESTADO                           0
# PRODUTO                          0
# NÚMERO DE POSTOS PESQUISADOS     0
# UNIDADE DE MEDIDA                0
# PREÇO MÉDIO REVENDA              0
# DESVIO PADRÃO REVENDA            0
# PREÇO MÍNIMO REVENDA             0
# PREÇO MÁXIMO REVENDA             0
# MARGEM MÉDIA REVENDA             0
# COEF DE VARIAÇÃO REVENDA         0
# PREÇO MÉDIO DISTRIBUIÇÃO         0
# DESVIO PADRÃO DISTRIBUIÇÃO       0
# PREÇO MÍNIMO DISTRIBUIÇÃO        0
# PREÇO MÁXIMO DISTRIBUIÇÃO        0
# COEF DE VARIAÇÃO DISTRIBUIÇÃO    0
# dtype: int64

# %%
import locale

#Importa locale para formatação de números

# %%
locale.setlocale(locale.LC_ALL, 'pt_BR.UTF-8')

#Configura o locale para padrão brasileiro
# Out:
# 'pt_BR.UTF-8'

# %%
pd.options.display.float_format = lambda x: locale.format_string("%.2f", x, grouping = True, monetary=True)

#Configura a função de formatação e limita em duas casas decimais

# %%
data

#Imprime base de dados com a formatação utf-8
# Out:
#        DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0        2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1        2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2        2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3        2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4        2004-05-09  2004-05-15      NORDESTE             ALAGOAS
# ...             ...         ...           ...                 ...
# 120818   2021-04-25  2021-05-01         NORTE             RORAIMA
# 120819   2021-04-25  2021-05-01           SUL      SANTA CATARINA
# 120820   2021-04-25  2021-05-01       SUDESTE           SAO PAULO
# 120821   2021-04-25  2021-05-01      NORDESTE             SERGIPE
# 120822   2021-04-25  2021-05-01         NORTE           TOCANTINS
#
#                  PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0       ETANOL HIDRATADO                           127              R$/l
# ...

# %%
data.head(10)
#destacando as 10 primeiras linhas do dataset
# Out:
#   DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0   2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1   2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2   2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3   2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4   2004-05-09  2004-05-15      NORDESTE             ALAGOAS
# 5   2004-05-09  2004-05-15      NORDESTE               BAHIA
# 6   2004-05-09  2004-05-15      NORDESTE               CEARA
# 7   2004-05-09  2004-05-15      NORDESTE            MARANHAO
# 8   2004-05-09  2004-05-15      NORDESTE             PARAIBA
# 9   2004-05-09  2004-05-15      NORDESTE          PERNAMBUCO
#
#             PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0  ETANOL HIDRATADO                           127              R$/l
# 1  ETANOL HIDRATADO                           387              R$/l
# 2  ETANOL HIDRATADO                           192              R$/l
# ...

# %%
data["ESTADO"].unique()

#mostrando os estados analisados pela pesquisa
# Out:
# array(['DISTRITO FEDERAL', 'GOIAS', 'MATO GROSSO', 'MATO GROSSO DO SUL',
#        'ALAGOAS', 'BAHIA', 'CEARA', 'MARANHAO', 'PARAIBA', 'PERNAMBUCO',
#        'PIAUI', 'RIO GRANDE DO NORTE', 'SERGIPE', 'ACRE', 'AMAPA',
#        'AMAZONAS', 'PARA', 'RONDONIA', 'RORAIMA', 'TOCANTINS',
#        'ESPIRITO SANTO', 'MINAS GERAIS', 'RIO DE JANEIRO', 'SAO PAULO',
#        'PARANA', 'RIO GRANDE DO SUL', 'SANTA CATARINA'], dtype=object)

# %%
data["PRODUTO"].unique()

#mostrando produtos analisados pela pesquisa
# Out:
# array(['ETANOL HIDRATADO', 'GASOLINA COMUM', 'GLP', 'GNV', 'ÓLEO DIESEL',
#        'ÓLEO DIESEL S10', 'OLEO DIESEL', 'OLEO DIESEL S10',
#        'GASOLINA ADITIVADA'], dtype=object)

# %%
data.duplicated()
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 120818    False
# 120819    False
# 120820    False
# 120821    False
# 120822    False
# Length: 120823, dtype: bool

# %%
data.sort_values(by=['ESTADO']).head(10)
#seleciona e mostra 10 linhas da coluna 'estado' em ordem alfabética
# Out:
#        DATA INICIAL  DATA FINAL REGIÃO ESTADO           PRODUTO  \
# 19555    2009-09-27  2009-10-03  NORTE   ACRE    GASOLINA COMUM
# 111240   2020-01-19  2020-01-25  NORTE   ACRE               GLP
# 96718    2018-03-11  2018-03-17  NORTE   ACRE               GLP
# 70195    2014-10-26  2014-11-01  NORTE   ACRE               GLP
# 56212    2013-01-27  2013-02-02  NORTE   ACRE  ETANOL HIDRATADO
# 25522    2005-05-01  2005-05-07  NORTE   ACRE               GLP
# 44451    2004-12-26  2005-01-01  NORTE   ACRE       ÓLEO DIESEL
# 96691    2018-03-11  2018-03-17  NORTE   ACRE    GASOLINA COMUM
# 63375    2013-12-22  2013-12-28  NORTE   ACRE  ETANOL HIDRATADO
# 3788     2007-01-28  2007-02-03  NORTE   ACRE  ETANOL HIDRATADO
#
#         NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# 19555                             33              R$/l                 2,97
# 111240                            27           R$/13Kg                84,78
# ...

# %%
data.sort_values(by=['REGIÃO', 'ESTADO']).head(10)

#seleciona e mostra o resultado de 10 semanas de pesquisa na região centro oeste, especificamente no distrito federal com foco no produto etanol
# Out:
#     DATA INICIAL  DATA FINAL        REGIÃO            ESTADO  \
# 0     2004-05-09  2004-05-15  CENTRO OESTE  DISTRITO FEDERAL
# 27    2004-05-16  2004-05-22  CENTRO OESTE  DISTRITO FEDERAL
# 54    2004-05-23  2004-05-29  CENTRO OESTE  DISTRITO FEDERAL
# 81    2004-05-30  2004-06-05  CENTRO OESTE  DISTRITO FEDERAL
# 108   2004-06-06  2004-06-12  CENTRO OESTE  DISTRITO FEDERAL
# 135   2004-06-13  2004-06-19  CENTRO OESTE  DISTRITO FEDERAL
# 162   2004-06-20  2004-06-26  CENTRO OESTE  DISTRITO FEDERAL
# 189   2004-06-27  2004-07-03  CENTRO OESTE  DISTRITO FEDERAL
# 216   2004-07-04  2004-07-10  CENTRO OESTE  DISTRITO FEDERAL
# 243   2004-07-11  2004-07-17  CENTRO OESTE  DISTRITO FEDERAL
#
#               PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0    ETANOL HIDRATADO                           127              R$/l
# 27   ETANOL HIDRATADO                           144              R$/l
# 54   ETANOL HIDRATADO                           129              R$/l
# ...

# %%
pernambuco_data = data[data['ESTADO'] == 'PERNAMBUCO']

#atribui à variavel pernambuco_data um valor que seleciona no dataset apenas as linhas onde o valor da coluna 'estado' é 'pernambuco'

# %%
pernambuco_data 

#mostra a variável anterior onde apenas o resultado da pesquisa no estado de pernambuco foi selecionado .
# Out:
#        DATA INICIAL  DATA FINAL    REGIÃO      ESTADO           PRODUTO  \
# 9        2004-05-09  2004-05-15  NORDESTE  PERNAMBUCO  ETANOL HIDRATADO
# 36       2004-05-16  2004-05-22  NORDESTE  PERNAMBUCO  ETANOL HIDRATADO
# 63       2004-05-23  2004-05-29  NORDESTE  PERNAMBUCO  ETANOL HIDRATADO
# 90       2004-05-30  2004-06-05  NORDESTE  PERNAMBUCO  ETANOL HIDRATADO
# 117      2004-06-06  2004-06-12  NORDESTE  PERNAMBUCO  ETANOL HIDRATADO
# ...             ...         ...       ...         ...               ...
# 120715   2021-04-25  2021-05-01  NORDESTE  PERNAMBUCO    GASOLINA COMUM
# 120742   2021-04-25  2021-05-01  NORDESTE  PERNAMBUCO               GLP
# 120762   2021-04-25  2021-05-01  NORDESTE  PERNAMBUCO               GNV
# 120785   2021-04-25  2021-05-01  NORDESTE  PERNAMBUCO       OLEO DIESEL
# 120812   2021-04-25  2021-05-01  NORDESTE  PERNAMBUCO   OLEO DIESEL S10
#
#         NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# ...

# %%
pernambucosemana1_data = data[(data['ESTADO'] == 'PERNAMBUCO') & 
                       (data['DATA INICIAL'] == '2004-05-09') & 
                       (data['DATA FINAL'] == '2004-05-15')]

#armazenando na variavel pernambucosemana1_data um valor que seleciona a primeira semana de pesquisa no estado de pernambuco

# %%
pernambucosemana1_data
# Out:
#       DATA INICIAL  DATA FINAL    REGIÃO      ESTADO           PRODUTO  \
# 9       2004-05-09  2004-05-15  NORDESTE  PERNAMBUCO  ETANOL HIDRATADO
# 12073   2004-05-09  2004-05-15  NORDESTE  PERNAMBUCO    GASOLINA COMUM
# 24141   2004-05-09  2004-05-15  NORDESTE  PERNAMBUCO               GLP
# 36201   2004-05-09  2004-05-15  NORDESTE  PERNAMBUCO               GNV
# 43556   2004-05-09  2004-05-15  NORDESTE  PERNAMBUCO       ÓLEO DIESEL
#
#        NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# 9                               423              R$/l                 1,22
# 12073                           478              R$/l                 2,01
# 24141                           201           R$/13Kg                32,90
# 36201                            29             R$/m3                 1,15
# 43556                           398              R$/l                 1,35
#
#        DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  PREÇO MÁXIMO REVENDA  \
# ...

# %%
pernambucosemana2_data = data[(data['ESTADO'] == 'PERNAMBUCO') & 
                       (data['DATA INICIAL'] == '2021-04-25') & 
                       (data['DATA FINAL'] == '2021-05-01')]

#armazenando na variavel pernambucosemana2_data o valor que seleciona a ultima semana de pesquisa no estado de pernambuco

# %%
pernambucosemana2_data
#imprimindo variavel
# Out:
#        DATA INICIAL  DATA FINAL    REGIÃO      ESTADO             PRODUTO  \
# 120661   2021-04-25  2021-05-01  NORDESTE  PERNAMBUCO    ETANOL HIDRATADO
# 120688   2021-04-25  2021-05-01  NORDESTE  PERNAMBUCO  GASOLINA ADITIVADA
# 120715   2021-04-25  2021-05-01  NORDESTE  PERNAMBUCO      GASOLINA COMUM
# 120742   2021-04-25  2021-05-01  NORDESTE  PERNAMBUCO                 GLP
# 120762   2021-04-25  2021-05-01  NORDESTE  PERNAMBUCO                 GNV
# 120785   2021-04-25  2021-05-01  NORDESTE  PERNAMBUCO         OLEO DIESEL
# 120812   2021-04-25  2021-05-01  NORDESTE  PERNAMBUCO     OLEO DIESEL S10
#
#         NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# 120661                            99              R$/l                 4,46
# 120688                            61              R$/l                 5,48
# 120715                            98              R$/l                 5,26
# ...

# %%
pernambucosemana3_data = data[(data['ESTADO'] == 'PERNAMBUCO') & 
                       (data['DATA INICIAL'] == '2021-04-25') & 
                       (data['DATA FINAL'] == '2021-05-01') &
                       (data['PRODUTO'] == 'GASOLINA COMUM')]

#declarando variavel pernambucosemana3_data e atribuindo valor que seleciona a pesquisa realizada entre 25-04-2021 e 01-05-2021 no estado de pernambuco
#para gasolina comum

# %%
pernambucosemana3_data

#imprimindo variavel pernambucosemana3_data
# Out:
#        DATA INICIAL  DATA FINAL    REGIÃO      ESTADO         PRODUTO  \
# 120715   2021-04-25  2021-05-01  NORDESTE  PERNAMBUCO  GASOLINA COMUM
#
#         NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# 120715                            98              R$/l                 5,26
#
#         DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  PREÇO MÁXIMO REVENDA  \
# 120715                   0,13                  4,99                  5,60
#
#        MARGEM MÉDIA REVENDA  COEF DE VARIAÇÃO REVENDA  \
# 120715             -99999.0                      0,03
#
#        PREÇO MÉDIO DISTRIBUIÇÃO DESVIO PADRÃO DISTRIBUIÇÃO  \
# 120715                 -99999.0                   -99999.0
#
#        PREÇO MÍNIMO DISTRIBUIÇÃO PREÇO MÁXIMO DISTRIBUIÇÃO  \
# 120715                  -99999.0                  -99999.0
#
#        COEF DE VARIAÇÃO DISTRIBUIÇÃO
# 120715                      -99999.0

# %%
saopaulodezembro2019_data = data[(data['ESTADO'] == 'SAO PAULO') & 
                       (data['DATA INICIAL'] == '2019-12-01') & 
                       (data['DATA FINAL'] == '2019-12-07')]

#declarando variavel saopaulodezembro2019_data e atribuindo valor que seleciona o resultado da pesquisa no primeiro mês de dezembro de 2019 no estado de 
#são paulo

# %%
saopaulodezembro2019_data

#imprimindo variavel saopaulodezembro2019_data
# Out:
#        DATA INICIAL  DATA FINAL   REGIÃO     ESTADO           PRODUTO  \
# 110148   2019-12-01  2019-12-07  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 110175   2019-12-01  2019-12-07  SUDESTE  SAO PAULO    GASOLINA COMUM
# 110202   2019-12-01  2019-12-07  SUDESTE  SAO PAULO               GLP
# 110218   2019-12-01  2019-12-07  SUDESTE  SAO PAULO               GNV
# 110244   2019-12-01  2019-12-07  SUDESTE  SAO PAULO       OLEO DIESEL
# 110271   2019-12-01  2019-12-07  SUDESTE  SAO PAULO   OLEO DIESEL S10
#
#         NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# 110148                          1664              R$/l                 2,88
# 110175                          1641              R$/l                 4,26
# 110202                          1017           R$/13Kg                67,94
# 110218                            50             R$/m3                 3,00
# 110244                           801              R$/l                 3,62
# ...

# %%
pernambucosemanalockdown_data = data[(data['ESTADO'] == 'PERNAMBUCO') & 
                       (data['DATA INICIAL'] == '2020-04-19') & 
                       (data['DATA FINAL'] == '2020-04-25')]


#declara variavel pernambucosemanalockdown_data e atribui valor que seleciona o resultado da pesquisa no estado de pernambuco durante a primeira semana de
#lockdown na pandemia de covid 19

# %%
pernambucosemanalockdown_data
# Out:
#        DATA INICIAL  DATA FINAL    REGIÃO      ESTADO           PRODUTO  \
# 113171   2020-04-19  2020-04-25  NORDESTE  PERNAMBUCO  ETANOL HIDRATADO
# 113198   2020-04-19  2020-04-25  NORDESTE  PERNAMBUCO    GASOLINA COMUM
# 113225   2020-04-19  2020-04-25  NORDESTE  PERNAMBUCO               GLP
# 113246   2020-04-19  2020-04-25  NORDESTE  PERNAMBUCO               GNV
# 113269   2020-04-19  2020-04-25  NORDESTE  PERNAMBUCO       OLEO DIESEL
# 113296   2020-04-19  2020-04-25  NORDESTE  PERNAMBUCO   OLEO DIESEL S10
#
#         NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# 113171                           173              R$/l                 3,35
# 113198                           191              R$/l                 3,85
# 113225                           165           R$/13Kg                65,51
# 113246                             8             R$/m3                 2,80
# 113269                            10              R$/l                 3,36
# ...

# %%
pernambucosemana2_data = data[(data['ESTADO'] == 'PERNAMBUCO') & 
                       (data['DATA INICIAL'] == '2021-04-25') & 
                       (data['DATA FINAL'] == '2021-05-01')]
